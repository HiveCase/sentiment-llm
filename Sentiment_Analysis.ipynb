# %% [markdown]
# <a href="https://colab.research.google.com/github/HiveCase/sentiment-llm/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from google.colab import userdata

api_key = userdata.get('OPENAI_API_KEY')
api_key = api_key.strip()

# %%
r = requests.get("http://aiproxy.sanand.workers.dev/openai/v1/chat/completions", headers={
    "Authorization": f"Bearer {api_key}"
    })
r.json()["data"][:2]
# Out:
# [{'object': 'chat.completion',
#   'id': 'chatcmpl-B0gyVdzgLGZjq439tR9PBWPXUkfou',
#   'model': 'gpt-4o-mini-2024-07-18',
#   'created': 1739504895,
#   'request_id': 'req_4550cce2928129b707e546afc177d67c',
#   'tool_choice': None,
#   'usage': {'total_tokens': 294,
#    'completion_tokens': 279,
#    'prompt_tokens': 15},
#   'seed': -7815656292804920000,
#   'top_p': 1,
#   'temperature': 1,
#   'presence_penalty': 0,
#   'frequency_penalty': 0,
#   'system_fingerprint': 'fp_00428b782a',
#   'input_user': None,
#   'service_tier': 'default',
#   'tools': None,
#   'metadata': {},
#   'choices': [{'index': 0,
# ...

# %%
import pandas as pd
reviews = pd.read_csv("movie_reviews.csv")

# %%
reviews.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
